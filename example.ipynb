# %%
# !pip install -e .
# Out:
# Obtaining file:///home/sakib/r8-film-interpolator
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting tensorflow==2.8.0 (from smoothee==0.0.1)
#   Using cached tensorflow-2.8.0-cp39-cp39-manylinux2010_x86_64.whl (497.6 MB)
# Collecting tensorflow-datasets==4.4.0 (from smoothee==0.0.1)
#   Using cached tensorflow_datasets-4.4.0-py3-none-any.whl (4.0 MB)
# Collecting tensorflow-addons==0.16.1 (from smoothee==0.0.1)
#   Using cached tensorflow_addons-0.16.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Collecting absl-py==0.12.0 (from smoothee==0.0.1)
#   Using cached absl_py-0.12.0-py3-none-any.whl (129 kB)
# Collecting gin-config==0.5.0 (from smoothee==0.0.1)
#   Using cached gin_config-0.5.0-py3-none-any.whl (61 kB)
# Collecting parameterized==0.8.1 (from smoothee==0.0.1)
#   Using cached parameterized-0.8.1-py2.py3-none-any.whl (26 kB)
# Collecting mediapy==1.0.3 (from smoothee==0.0.1)
#   Using cached mediapy-1.0.3-py3-none-any.whl (24 kB)
# Collecting scikit-image==0.19.1 (from smoothee==0.0.1)
#   Using cached scikit_image-0.19.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.8 MB)
# Collecting imageio[ffmpeg] (from smoothee==0.0.1)
#   Using cached imageio-2.33.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: six in ./.venv/lib/python3.9/site-packages (from absl-py==0.12.0->smoothee==0.0.1) (1.16.0)
# Requirement already satisfied: ipython in ./.venv/lib/python3.9/site-packages (from mediapy==1.0.3->smoothee==0.0.1) (8.18.1)
# Collecting matplotlib (from mediapy==1.0.3->smoothee==0.0.1)
#   Using cached matplotlib-3.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting numpy (from mediapy==1.0.3->smoothee==0.0.1)
#   Using cached numpy-1.26.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting Pillow (from mediapy==1.0.3->smoothee==0.0.1)
#   Using cached Pillow-10.1.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting scipy>=1.4.1 (from scikit-image==0.19.1->smoothee==0.0.1)
#   Using cached scipy-1.11.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting networkx>=2.2 (from scikit-image==0.19.1->smoothee==0.0.1)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2019.7.26 (from scikit-image==0.19.1->smoothee==0.0.1)
#   Using cached tifffile-2023.9.26-py3-none-any.whl.metadata (30 kB)
# Collecting PyWavelets>=1.1.1 (from scikit-image==0.19.1->smoothee==0.0.1)
#   Using cached pywavelets-1.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.9/site-packages (from scikit-image==0.19.1->smoothee==0.0.1) (23.2)
# Collecting astunparse>=1.6.0 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=1.12 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast>=0.2.1 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting h5py>=2.9.0 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached h5py-3.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting libclang>=9.0.1 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached protobuf-4.25.1-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (from tensorflow==2.8.0->smoothee==0.0.1) (58.1.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.venv/lib/python3.9/site-packages (from tensorflow==2.8.0->smoothee==0.0.1) (4.8.0)
# Collecting wrapt>=1.11.0 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached wrapt-1.16.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached tensorflow_io_gcs_filesystem-0.34.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached grpcio-1.59.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting typeguard>=2.7 (from tensorflow-addons==0.16.1->smoothee==0.0.1)
#   Using cached typeguard-4.1.5-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=18.1.0 (from tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting dill (from tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached dill-0.3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting future (from tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached future-0.18.3-py3-none-any.whl
# Collecting promise (from tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached promise-2.3-py3-none-any.whl
# Collecting requests>=2.19.0 (from tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tensorflow-metadata (from tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached tensorflow_metadata-1.14.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting tqdm (from tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting imageio-ffmpeg (from imageio[ffmpeg]->smoothee==0.0.1)
#   Using cached imageio_ffmpeg-0.4.9-py3-none-manylinux2010_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: psutil in ./.venv/lib/python3.9/site-packages (from imageio[ffmpeg]->smoothee==0.0.1) (5.9.6)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19.0->tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached charset_normalizer-3.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached google_auth-2.24.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting werkzeug>=0.11.15 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in ./.venv/lib/python3.9/site-packages (from typeguard>=2.7->tensorflow-addons==0.16.1->smoothee==0.0.1) (7.0.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.9/site-packages (from ipython->mediapy==1.0.3->smoothee==0.0.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.9/site-packages (from ipython->mediapy==1.0.3->smoothee==0.0.1) (0.19.1)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.9/site-packages (from ipython->mediapy==1.0.3->smoothee==0.0.1) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.9/site-packages (from ipython->mediapy==1.0.3->smoothee==0.0.1) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.9/site-packages (from ipython->mediapy==1.0.3->smoothee==0.0.1) (2.17.2)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.9/site-packages (from ipython->mediapy==1.0.3->smoothee==0.0.1) (0.6.3)
# Requirement already satisfied: traitlets>=5 in ./.venv/lib/python3.9/site-packages (from ipython->mediapy==1.0.3->smoothee==0.0.1) (5.14.0)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.9/site-packages (from ipython->mediapy==1.0.3->smoothee==0.0.1) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.9/site-packages (from ipython->mediapy==1.0.3->smoothee==0.0.1) (4.9.0)
# Collecting contourpy>=1.0.1 (from matplotlib->mediapy==1.0.3->smoothee==0.0.1)
#   Using cached contourpy-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->mediapy==1.0.3->smoothee==0.0.1)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->mediapy==1.0.3->smoothee==0.0.1)
#   Using cached fonttools-4.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (156 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->mediapy==1.0.3->smoothee==0.0.1)
#   Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->mediapy==1.0.3->smoothee==0.0.1)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.9/site-packages (from matplotlib->mediapy==1.0.3->smoothee==0.0.1) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib->mediapy==1.0.3->smoothee==0.0.1)
#   Using cached importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting googleapis-common-protos<2,>=1.52.0 (from tensorflow-metadata->tensorflow-datasets==4.4.0->smoothee==0.0.1)
#   Using cached googleapis_common_protos-1.61.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: zipp>=0.5 in ./.venv/lib/python3.9/site-packages (from importlib-metadata>=3.6->typeguard>=2.7->tensorflow-addons==0.16.1->smoothee==0.0.1) (3.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython->mediapy==1.0.3->smoothee==0.0.1) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython->mediapy==1.0.3->smoothee==0.0.1) (0.7.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->mediapy==1.0.3->smoothee==0.0.1) (0.2.12)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached MarkupSafe-2.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython->mediapy==1.0.3->smoothee==0.0.1) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.9/site-packages (from stack-data->ipython->mediapy==1.0.3->smoothee==0.0.1) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.9/site-packages (from stack-data->ipython->mediapy==1.0.3->smoothee==0.0.1) (0.2.2)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0->smoothee==0.0.1)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached grpcio-1.59.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
# Using cached h5py-3.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# Using cached imageio-2.33.0-py3-none-any.whl (313 kB)
# Using cached libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached numpy-1.26.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached Pillow-10.1.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.6 MB)
# Using cached pywavelets-1.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached scipy-1.11.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.6 MB)
# Using cached tensorflow_io_gcs_filesystem-0.34.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached tifffile-2023.9.26-py3-none-any.whl (222 kB)
# Using cached typeguard-4.1.5-py3-none-any.whl (34 kB)
# Using cached wrapt-1.16.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Using cached dill-0.3.7-py3-none-any.whl (115 kB)
# Using cached imageio_ffmpeg-0.4.9-py3-none-manylinux2010_x86_64.whl (26.9 MB)
# Using cached matplotlib-3.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Using cached tensorflow_metadata-1.14.0-py3-none-any.whl (28 kB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Using cached contourpy-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Using cached google_auth-2.24.0-py2.py3-none-any.whl (183 kB)
# Using cached googleapis_common_protos-1.61.0-py2.py3-none-any.whl (230 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Using cached importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Using cached kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached Markdown-3.5.1-py3-none-any.whl (102 kB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Using cached MarkupSafe-2.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Building wheels for collected packages: smoothee
#   Building editable for smoothee (pyproject.toml) ... done
#   Created wheel for smoothee: filename=smoothee-0.0.1-0.editable-py3-none-any.whl size=4714 sha256=1e99d522bc20c540bf7a56e8a8cd2a8faf89334ab2d0e3d309803ceb5d9346ec
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mt852tvo/wheels/3f/b3/ed/b9a2877065a8e01ac783a1e87fb41307e6a46f816ae7c2c067
# Successfully built smoothee
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, parameterized, libclang, keras, gin-config, flatbuffers, wrapt, wheel, urllib3, tqdm, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, pyparsing, pyasn1, protobuf, promise, Pillow, oauthlib, numpy, networkx, MarkupSafe, kiwisolver, importlib-resources, imageio-ffmpeg, idna, grpcio, google-pasta, gast, future, fonttools, dill, cycler, charset-normalizer, certifi, cachetools, attrs, absl-py, werkzeug, typeguard, tifffile, scipy, rsa, requests, PyWavelets, pyasn1-modules, opt-einsum, markdown, keras-preprocessing, imageio, h5py, googleapis-common-protos, contourpy, astunparse, tensorflow-metadata, tensorflow-addons, scikit-image, requests-oauthlib, matplotlib, google-auth, tensorflow-datasets, mediapy, google-auth-oauthlib, tensorboard, tensorflow, smoothee
# Successfully installed MarkupSafe-2.1.3 Pillow-10.1.0 PyWavelets-1.5.0 absl-py-0.12.0 astunparse-1.6.3 attrs-23.1.0 cachetools-5.3.2 certifi-2023.11.17 charset-normalizer-3.3.2 contourpy-1.2.0 cycler-0.12.1 dill-0.3.7 flatbuffers-23.5.26 fonttools-4.46.0 future-0.18.3 gast-0.5.4 gin-config-0.5.0 google-auth-2.24.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 googleapis-common-protos-1.61.0 grpcio-1.59.3 h5py-3.10.0 idna-3.6 imageio-2.33.0 imageio-ffmpeg-0.4.9 importlib-resources-6.1.1 keras-2.8.0 keras-preprocessing-1.1.2 kiwisolver-1.4.5 libclang-16.0.6 markdown-3.5.1 matplotlib-3.8.2 mediapy-1.0.3 networkx-3.2.1 numpy-1.26.2 oauthlib-3.2.2 opt-einsum-3.3.0 parameterized-0.8.1 promise-2.3 protobuf-3.20.3 pyasn1-0.5.1 pyasn1-modules-0.3.0 pyparsing-3.1.1 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 scikit-image-0.19.1 scipy-1.11.4 smoothee-0.0.1 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-addons-0.16.1 tensorflow-datasets-4.4.0 tensorflow-io-gcs-filesystem-0.34.0 tensorflow-metadata-1.14.0 termcolor-2.4.0 tf-estimator-nightly-2.8.0.dev2021122109 tifffile-2023.9.26 tqdm-4.66.1 typeguard-4.1.5 urllib3-2.1.0 werkzeug-3.0.1 wheel-0.42.0 wrapt-1.16.0

# %%
from pathlib import Path
from smoothee import Film

# Initialize the Film and specify the input and output files
film_interp = Film()
input_mp4_path = Path("./input.mp4")  # x fps video with y frames
output_file_path = Path("./smoothee_output.mp4")

# Perform frame interpolation and print the path to the output video
output_file = film_interp.interp(
    input_mp4_path=input_mp4_path,
    output_mp4_path=output_file_path,
    playback_frames_per_second=24,
    num_interpolation_steps=1,
)

print(
    f"Interpolated video saved at: {output_file_path}"
)  # 2*x fps video with (2*y-1) frames
# Out:
# 2023-12-05 13:43:26.681242: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-12-05 13:43:26.681294: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# [!] File already exists at destination: smoothee/film/frame_interpolation_saved_model/keras_metadata.pb. No download needed.[!] File already exists at destination: smoothee/film/frame_interpolation_saved_model/saved_model.pb. No download needed.
#
# [!] File already exists at destination: smoothee/film/frame_interpolation_saved_model/variables/variables.data-00000-of-00001. No download needed.
# [!] File already exists at destination: smoothee/film/frame_interpolation_saved_model/variables/variables.index. No download needed.
# [!] Loading interpolator...
# 2023-12-05 13:43:28.049735: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-05 13:43:28.053492: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-12-05 13:43:28.053574: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-12-05 13:43:28.053644: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-12-05 13:43:28.053704: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-12-05 13:43:28.053764: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2023-12-05 13:43:28.053824: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2023-12-05 13:43:28.053889: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-12-05 13:43:28.053951: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-12-05 13:43:28.053963: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-12-05 13:43:28.305758: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'input.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:02.00, start: 0.000000, bitrate: 2458 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 768x512, 2454 kb/s, 8 fps, 8 tbr, 16384 tbn, 16 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'frames/%04d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: png, rgb24(pc, gbr/unknown/unknown, progressive), 768x512, q=2-31, 200 kb/s, 8 fps, 8 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 png
# frame=   16 fps=0.0 q=-0.0 Lsize=N/A time=00:00:02.00 bitrate=N/A speed=15.4x
# video:10593kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# [!] Interpolating frames with FILM...
#   0%|                                                                        | 0/15 [00:00<?, ?it/s]2023-12-05 13:43:38.364003: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 317718528 exceeds 10% of free system memory.
#   7%|████▎                                                           | 1/15 [00:07<01:44,  7.48s/it]2023-12-05 13:43:44.006619: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 317718528 exceeds 10% of free system memory.
#  13%|████████▌                                                       | 2/15 [00:13<01:23,  6.40s/it]2023-12-05 13:43:49.532056: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 317718528 exceeds 10% of free system memory.
#  20%|████████████▊                                                   | 3/15 [00:18<01:12,  6.00s/it]2023-12-05 13:43:55.076734: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 317718528 exceeds 10% of free system memory.
#  27%|█████████████████                                               | 4/15 [00:24<01:04,  5.82s/it]2023-12-05 13:44:00.598715: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 317718528 exceeds 10% of free system memory.
# 100%|███████████████████████████████████████████████████████████████| 15/15 [01:24<00:00,  5.61s/it]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from 'frames/interpolated_frames/%08d.png':
#   Duration: 00:00:01.24, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 768x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x556e1f77bd40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x556e1f77bd40] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x556e1f77bd40] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'smoothee_output.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 768x512, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# [!] Output video saved at: smoothee_output.mp4
# Interpolated video saved at: smoothee_output.mp4
# frame=   31 fps=0.0 q=-1.0 Lsize=    5117kB time=00:00:01.16 bitrate=35928.0kbits/s speed= 2.4x
# video:5116kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.024186%
# [libx264 @ 0x556e1f77bd40] frame I:1     Avg QP: 3.35  size:175149
# [libx264 @ 0x556e1f77bd40] frame P:16    Avg QP: 3.54  size:196198
# [libx264 @ 0x556e1f77bd40] frame B:14    Avg QP: 6.04  size:137399
# [libx264 @ 0x556e1f77bd40] consecutive B-frames:  9.7% 90.3%  0.0%  0.0%
# [libx264 @ 0x556e1f77bd40] mb I  I16..4:  6.0% 53.6% 40.4%
# [libx264 @ 0x556e1f77bd40] mb P  I16..4:  1.2%  6.8% 31.5%  P16..4: 16.3% 27.1% 17.0%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x556e1f77bd40] mb B  I16..4:  0.0%  0.0%  0.1%  B16..8: 34.5% 29.1% 21.4%  direct:14.5%  skip: 0.3%  L0:24.4% L1:26.2% BI:49.5%
# [libx264 @ 0x556e1f77bd40] 8x8 transform intra:22.1% inter:28.3%
# [libx264 @ 0x556e1f77bd40] coded y,uvDC,uvAC intra: 100.0% 98.2% 97.1% inter: 99.3% 91.3% 85.8%
# [libx264 @ 0x556e1f77bd40] i16 v,h,dc,p:  2% 26% 41% 30%
# [libx264 @ 0x556e1f77bd40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  4% 30% 16%  6%  8%  4% 13%  4% 14%
# [libx264 @ 0x556e1f77bd40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6% 22% 12%  8% 11%  6% 15%  6% 14%
# [libx264 @ 0x556e1f77bd40] i8c dc,h,v,p: 42% 43%  7%  8%
# [libx264 @ 0x556e1f77bd40] Weighted P-Frames: Y:18.8% UV:0.0%
# [libx264 @ 0x556e1f77bd40] ref P L0: 70.5% 27.1%  2.1%  0.3%  0.0%
# [libx264 @ 0x556e1f77bd40] ref B L0: 99.9%  0.1%
# [libx264 @ 0x556e1f77bd40] kb/s:32441.22
